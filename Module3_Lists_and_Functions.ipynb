# %% [markdown]
# # Module 3 Programming Assignment – Lists and Functions
# Name: Jesse Chapa
# Course: SDEV 220
# Date: 2026-01-29
#
# Chapters: 7 and 9 (“Things to Do”)
# Completed: 7.4, 7.5, 7.6, 7.7, 9.1, 9.2

# %% [markdown]
# ## 7.4
# Make a list called `things` with:
# "mozzarella", "cinderella", "salmonella"

# %%
things = ["mozzarella", "cinderella", "salmonella"]
things
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# ## 7.5
# Capitalize the element that refers to a person and print the list.
# Did it change the element in the list? Yes

# %%
things[1] = things[1].capitalize()
things
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# ## 7.6
# Make the cheesy element (mozzarella) all uppercase and print the list.

# %%
things[0] = things[0].upper()
things
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# ## 7.7
# Delete the disease element (salmonella) and print the list.

# %%
del things[2]
things
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# ## 9.1
# Define a function called `good()` that returns:
# ['Harry', 'Ron', 'Hermione']

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# ## 9.2
# Define a generator function called `get_odds()` that returns the odd numbers from `range(10)`.
# Use a for loop to find and print the third value returned.

# %%
def get_odds():
    for n in range(10):
        if n % 2 == 1:
            yield n

count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print("Third odd number:", odd)
        break
# Out:
# Third odd number: 5
